# %% [markdown]
# ***PROBLEMA DO CRONOGRAMA DA SALA DE AULA***
#
# Obj: Escolher um cronograma com mais aulas em uma sala de aula
#
# ![image.png](attachment:image.png)
#
# Para isso, o algoritmo é bem simples na real: A cada etapa, escolhe-se a solução ideal, e no fim você te uma solução global ideal.
#
# Neste caso, o ideal é escolher a aula que termina mais cedo, depois, escolher a próxima que termine mais cedo dps da primeira, e assim vai....
#
# Simples, pode errar em certos casos, mas funciona para muitos!
#
# ![image-2.png](attachment:image-2.png)
#
#
# Mas, quando erram, geralmente erram por pouco!

# %% [markdown]
# ***PROBLEMA DA MOCHILA***
#
# Temos uma bolsa que suporta 16 quilos e queremos pegar o máximo de dinheiro possível, roubando uns itens.
#
#
# ![image.png](attachment:image.png)
#
# O algoritmo aqui é simples: Pega o mais caro que a bolsa aguenta, até não conseguir mais.
#
# Aqui ele erra, pq retorna R$ 3000, quando o melhor possível é R$ 3500, mas é bem próximo do melhor.

# %% [markdown]
# ***O PROBLEMA DA COBERTURA DE CONJUNTOS***
#
#
# ![image.png](attachment:image.png)
#
#
# CONJUNTO DE PARTES
# ![image-2.png](attachment:image-2.png)
#
#
# Para resolver isso, usamos algoritmos de aproximação. São usados:
# - por sua rapidez;
# - pela capacidade de chegar à solução ideal.

# %%
estados_abranger = set(["mt", "wa", "or", "id", "nv", "ut","ca",
"az"])

# %%
estacoes = {}
estacoes["kum"] = set(["id", "nv", "ut"])
estacoes["kdois"] = set(["wa", "id", "mt"])
estacoes["ktres"] = set(["or", "nv", "ca"])
estacoes["kquatro"] = set(["nv", "ut"])
estacoes["kcinco"] = set(["ca", "az"])

# %%
estacoes_finais = set()

# %%
while estados_abranger:
    melhor_estacao = None
    estados_cobertos = set()
    for estacao, estados in estacoes.items():
        cobertos = estados_abranger & estados
        if len(cobertos) > len(estados_cobertos):
            melhor_estacao = estacao
            estados_cobertos = cobertos
    estados_abranger -= estados_cobertos
    estacoes_finais.add(melhor_estacao)

print(estacoes_finais)
# Out:
# {'kdois', 'ktres', 'kcinco', 'kum'}

# %%
frutas = set(["abacate", "tomate", "banana"])
vegetais = set(["beterraba", "cenoura", "tomate"])

print(frutas | vegetais)

# set(["abacate", "beterraba", "cenoura", "tomate", "banana"])

print(frutas & vegetais) 

#set(["tomate"])

print(frutas - vegetais) 

# set(["abacate", "banana"])

print(vegetais - frutas)
# Out:
# {'cenoura', 'beterraba', 'banana', 'tomate', 'abacate'}
# {'tomate'}
# {'abacate', 'banana'}
# {'cenoura', 'beterraba'}

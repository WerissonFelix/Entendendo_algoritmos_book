# %% [markdown]
# ***ALGORITMO DE DIJKSTRA***
#
# Trabalha com grafos ponderados, cujas arestas possuem pesos. Ele retorna o menor peso total de  A para B, não o caminho mais curto necessariamente, mas o menor no sentido da soma dos pesos.
#
# ![image.png](attachment:image.png)
#
#
# Pesquisa em largura (caminho mais curto):
#
# ![image-2.png](attachment:image-2.png)
#
# Algoritmo de dijkstra (caminho com menor peso):
#
# ![image-3.png](attachment:image-3.png)
#
#
#
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ***TERMINOLOGIA***
#
#
# O algoritmo de Dijkstra só funciona com grafos acíclicos dirigidos (Directed Acyclic Graph, DAG)
# Um grafo não direcionado é um ciclo!!
#
# ![image.png](attachment:image.png)
#
# A ideia é criar uma tabela com os valores possíveis atuais e ir atualizando.
#
# No final, nós vamos escolhendo a opção correta indo do final até o início, seguindo seus respectivos pais
#
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)

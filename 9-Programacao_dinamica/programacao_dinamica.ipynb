# %% [markdown]
# ***PROGRAMAÇÃO DINÂMICA***
#
#
# Vamos pegar o problema da mochila do cap passado, o de roubar os itens lá. A ideia é dividir o problemão que temos me probleminhas, em partes. Ou seja, começamos com a resolução de subproblemas e vamos escalando até resolver o original.
#
#
# A ideia é fazer uma tabela que represente os subproblemas. Colunas = variações do problema; Linhas = itens.
#
# ![image.png](attachment:image.png)
#
# Cada célula da tabela conterá uma lista de todos os itens que cabem na mochila

# %% [markdown]
# Nós vamos preenchendo as linhas de acordo com a capacidade da mochila (coluna).
#
# ![image.png](attachment:image.png)
#
# É basicamente isso, saber qual é o melhor cenário para essas versões da mochila original, pois nós chegamos neste probleminha aqui:
#
# ![image-2.png](attachment:image-2.png)
#
# Na última célula (a vazia), temos 3000 do rádio contra 2000 do note, a questão é: ainda tem 1 kg sobrando pra a mochila do note, mas a do rádio já está cheia! E ADIVINHA já temos a melhor opção para 1 kg: o violão!
#
# ![image-3.png](attachment:image-3.png)
#
#
#
# ![image-4.png](attachment:image-4.png)
